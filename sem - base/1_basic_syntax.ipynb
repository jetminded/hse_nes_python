# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# Наука о Данных
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# <h3 style="font-size: 36px;">
# Введение в Python: переменные, работа со строками, циклы, условия.
# </h3>
#
# <p style="margin-top: 20px;">
# <strong>Дата:</strong> 27-28 января 2026 года<br>
# </p>
#
# <p style="margin-top: 25px;">
# Данный ноутбук является частью серии семинаров по курсу
# <em>«Наука о Данных»</em> и предназначен для учебных и образовательных целей.
# </p>
#
# </div>

# %% [markdown]
# Давай начнём погружаться в язык Python! Сегодня наша задача - сделать умное приложение для того, чтобы помочь бабушке с огородом на даче.

# %% [markdown]
# ## Задача 1. Подсчет количества дней
#
# Создай целочисленные переменные, которые отвечают за:
# - `days_for_seeding`: количество дней для проращивания семян
# - `days_for_growing`: количество дней для выращивания рассады
# - `days_before_fruiting`: количество дней до плодоношения
#
# Считай с клавиатуры все три переменные.
#
# Сложи все три переменные. Выведи на экран результат - число дней от момента начала проращивания семян до момента, когда созреют помидоры.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Задача 2. Сохранение данных о сорте.
#
# Продуктивность сорта считается по простой формуле - [количество кг, собранных со всех кустов] / [количество кустов]
#
# Считай с клавиатуры количество килограмм, собранных со всех кустов и количество кустов (целые числа). Подели и округли до 2 знаков после запятой, результат выведи на экран.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Задача 3. Средняя сладость клубники.
#
# Ваша бабушка поспорила с соседкой, у кого клубника более сладкая. Они посадили кусты, а потом попросили соседей оценить сладость клубники, собранной с каждого из кустов, по шкале от 0 до 10. Ваша задача - посчитать среднее для двух массивов и определить, у кого слаще клубника в среднем.
#
# **Посчитайте среднее при помощи цикла for**

# %%
grandma_strawberries = [5, 7, 10, 9, 3, 10]
neighbour_strawberries = [10, 6, 2, 3]


# YOUR CODE HERE

# %% [markdown]
# ## Задача 4. Средняя сладость клубники - 2.
#
# Ваша бабушка поспорила с соседкой, у кого клубника более сладкая. Они посадили кусты, а потом попросили соседей оценить сладость клубники, собранной с каждого из кустов, по шкале от 0 до 10. Ваша задача - посчитать среднее для двух массивов и определить, у кого слаще клубника в среднем.
#
# **Посчитайте среднее при помощи встроенных функций Python**

# %%
grandma_strawberries = [5, 7, 10, 9, 3, 10]
neighbour_strawberries = [10, 6, 2, 3]


# YOUR CODE HERE

# %% [markdown]
# ## Задача 5. Погода на улице.
#
# Сейчас весна, у вашей бабушки уже высажена рассада перцев в парник. Однако она боится заморозков. Ваша задача - считать с клавиатуры значение температуры:
#
# Если t<5, то надо вывести "Пожалуйста, закрой полностью парник - на улице холодно";
# если t от 5 до 10, то надо вывести "Пожалуйста, прикрой парник - на улице прохладно";
# если больше 10, то надо выввести "Пожалуйста, открой полностью парник - на улице тепло".

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Задача 6. Записи в дневнике.
#
# Вы решили оцифровать записи о растениях в дневнике.
#
# Пока не будет введено с клавиатуры STOP, считывай строки в следующем формате:
#
# - Первая строка имеет вид "Название растения - Название сорта", например: Томат - Бычье сердце
#
# - Во второй строке запись о сорте, например: "В этом году сильно болеет кладоспориозом"
#
# Сохраняй корректные записи в словарь словарей из списков (`correct: dict[dict[list[str]]]`), где первый ключ - название растения, второй ключ - название сорта, а в списке хранятся все отзывы.
#
# Если запись некорректна (первая строка не имеет вид "Название растения - Название сорта"), сохраняй её в список некорректных записей (`incorrect: list[str]`), объединив со второй строкой через \n.
#
# После окончания работы выведи все корректные записи, а потом - некорректные.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Задача 7. Список любимых томатов.
#
# У вашей бабушки есть любимые сорта томатов, но не все из них она посадила в этом году. У вас есть словарь, где ключ - название сорта, а по значению лежит количество кустов, высаженных в этом году.
#
# Ваша задача - вывести список сортов, которые были высажены в этом году (если высажено 0 кустов, то этот сорт в этом году не сажался).
#
# **Реши задачу при помощи цикла for**

# %%
tomatoes = {"Бычье сердце": 4, "Любаша": 1, "Титаник": 0, "Космонавт Волков": 7}

# YOUR CODE HERE

# %% [markdown]
# ## Задача 8. Список любимых томатов - 2.
#
# У вашей бабушки есть любимые сорта томатов, но не все из них она посадила в этом году. У вас есть словарь, где ключ - название сорта, а по значению лежит количество кустов, высаженных в этом году.
#
# Ваша задача - вывести список сортов, которые были высажены в этом году (если высажено 0 кустов, то этот сорт в этом году не сажался).
#
# **Реши задачу при помощи list comprehensions**

# %%
tomatoes = {"Бычье сердце": 4, "Любаша": 1, "Титаник": 0, "Космонавт Волков": 7}

# YOUR CODE HERE
