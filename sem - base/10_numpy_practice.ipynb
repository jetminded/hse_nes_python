# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# НОД - Основной Поток
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# <h3 style="font-size: 36px;">
# 10. Numpy: практика
# </h3>
#
# <p style="margin-top: 20px;">
# <strong>Дата:</strong> 07-08 апреля 2026 года<br>
# </p>
#
# <p style="margin-top: 25px;">
# Данный ноутбук является частью серии семинаров по курсу
# <em>«Практикум Python»</em> и предназначен для учебных и образовательных целей.
# </p>
#
# </div>

# %% [markdown]
# # I. Создание массивов
#
# 1. Создай 1D массив с числами от 10 до 50.
#
# 2. Создай матрицу 3 на 3 с числами от 1 до 9
#
# 3. Создай массив 10 случайных чисел от 0 до 1

# %%
# TODO

# %% [markdown]
# # II. Индексация. Слайсинг.
# 1. Достань первые пять элементов массива.
#
# 2. Разверни массив
#
# 3. Выбери все чётные числа из массива.

# %%
# TODO

# %% [markdown]
# # III. Базовая статистика.
#
# 1. Посчитай среднее, медиану и дисперсию массиа.
#
# 2. Найди минимальный и максимальный элемент (и их индексы).

# %%
# TODO

# %% [markdown]
# # IV. Операции с массивами.
#
# 1. Сложи, вычти, умножь два массива поэлементно.
#
# 2. Нормализуй массив (сделай их элементами от 0 до 1, см. нормализация)

# %%
# TODO

# %% [markdown]
# # V. Изменение размерностей. Бродкастинг.
#
# 1. Трансформируй массив из 12 элементов в матрицу 3х4.
#
# 2. Добавь 1D массив к каждому ряду 2D матрицы при помощи бродкастинга.

# %%
# TODO

# %% [markdown]
# # VI. Фильтры. Условия.
#
# 1. Замени все значения, большие, чем порог (например, 50) на 1, остальные - 0.
#
# 2. Достань все элементы внути определенного отрезка, например, 20 - 40.

# %%
# TODO

# %% [markdown]
# # VII. Работа с пропавшими значениями.
#
# 1. Создай массив с np.nan
#
# 2. Замени все nan'ы средним значением в массиве.
#
# Какие ещё есть специфические числа в numpy?

# %%
# TODO

# %% [markdown]
# # VIII. Агрегация по размерности пространства
#
# 1. Посчитай суммы по строкам и по колокнам в матрице.
#
# 2. Найди максимальное значение в каждой колонке.

# %%
# TODO

# %% [markdown]
# # IX. Работа с данными.
#
# 1. Симулируй покупки чего-либо в течение 30 дней при помощи случайных чисел.
#
# 2. Добавь шум и посчитай скользящие окна.

# %%
# TODO

# %% [markdown]
# # X. Correlation & Covariance
#
# Сгенерируй два случайных датасета и посчитай для них:
#
# - матрицу ковариаций
#
# - коэффициент корреляции

# %%
# TODO

# %% [markdown]
# # XI. Очистка данных
#
# 1. Сделай датасет с выбросами.
#
# 2. Оставь значения внутри 95 перцентиля.
#
# 3. Проведи стандартизацию данных через z-score нормализацию
#
# Какие ещё есть проблемы при очистке данных?

# %%
# TODO

# %% [markdown]
# # XII. Feature Engineering
#
# 1. Создай новые фичи при помощи математических операций (log, sqrt, возведение в степень)

# %%
# TODO
