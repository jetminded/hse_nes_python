# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# Лабораторная работа 3. Классы + декораторы.
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# </div>
#
#
# Мы открываем кофейню! В данном домашнем задании предлагается написать класс, который будет отвечать за работу нашей будущей модной кофейни на Покровском бульваре, где мы будем делать фильтр и айс латте на миндальном.

# %% [markdown]
# ## Задача 1. Начало. (5 баллов).
#
# Напиши класс `User` с полями `username` и `group`. Сделай класс `CoffeeShop` с полями `address`, `menu`. В меню должны храниться блюда, которые характеризуются `id` (некоторое id блюда), `name` (название блюда), `price` (цена за одно блюдо), `am_left` (количество блюд, которые эта кофейня ещё сможет подать, пока они не закончатся).

# %% [markdown]
# Вопрос: как лучше хранить блюда? Какого типа будет поле `menu`? Почему?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Вопрос: какие поля в `User`, `CoffeeShop` надо сделать приватными? (Добавить _ или __ в начало)? Почему?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Помимо прочего, у класса `CoffeeShop` должны быть:
#
# - метод `add_dish(dish)`, который добавляет в меню новое блюдо (внутрь передаётся словарь как из условия);
# - метод `delete_dish(id)`, который удаляет блюдо из меню по `id`;
# - метод `restock_dish(id, am)`, который увеличивает количество для блюда с этим `id` на количество `am`. `am` всегда передаётся в метод через название (`my_coffeeshop.restock_dish(10, am=5)` - ОК, `my_coffeeshop.restock_dish(42, 7)` - НЕ ОК)
# - итератор по блюдам, которые мы можем приготовить (количество не ноль) - реализуй его через генератор;
# - метод `form_order(id1, id2, ...)`, который принимает на вход произвольное число `id` блюд, уменьшает их количество в меню на один.

# %%
# TODO

# %%
# TODO - напиши примеры использования этого кода

# %% [markdown]
# ## Задача 2. Проверка наличия блюда. (5 баллов).
#
# Напиши декоратор `check_id`, который берёт все аргументы метода, не считая `self`, и проверяет, есть ли блюдо с этим `id` в меню.
#
# Если есть - всё ОК, выполняется метод; иначе - поднимается ошибка `NoDishError` (напиши её сам).

# %%
# TODO

# %%
# TODO - скопируй сюда код CoffeeShop, добавь этот декоратор к методу delete_dish, restock_dish, form_order
# и напиши примеры использования этих методов

# %% [markdown]
# Вопрос: Сработает ли твой код, если `id` передадут в метод по названию (например, `my_coffee_shop.delete_dish(id=20)`)? Как надо доработать код, чтобы код корректно работал в обоих вариантах передачи: и `my_coffee_shop.delete_dish(20)`, и `my_coffee_shop.delete_dish(id=20)`?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %%
# TODO - напиши тут исправленный код декоратора

# %%
# TODO - напиши тут примеры использования delete_dish с учётом исправленного декоратора

# %% [markdown]
# Теперь добавь к нему флаг `error_0_left` - если этот флаг `True`, то ошибка поднимается не только если блюда нет, но и если осталось 0 позиций этого блюда (мы не сможем его приготовить). По дефолту значение `False`.
#
# Пример использования:
#
# ```python
# class CoffeeShop:
#     @check_id()
#     def delete_dish(...): ...
#
#     @check_id(error_0_left=True)
#     def form_order(...): ...
# ```

# %%
# TODO - напиши тут исправленный код декоратора

# %%
# TODO - напиши тут примеры использования form_order с учётом исправленного декоратора

# %% [markdown]
# ## Задача 3. Логгер. (3 балла).
#
# Напиши декоратор `logger(file)`, который в случае вызова метода записывает в файл лог (время; имя пользователя; название метода).
#
# P.S. Вспомни задание про `TransactionHistory`.

# %%
# TODO

# %%
# TODO - скопируй сюда код CoffeeShop из задачи 2, добавь этот декоратор к методу add_dish, delete_dish
# и напиши примеры использования этого метода

# %% [markdown]
# ## Задача 4. Сохранение состояния. (3 балла).
#
# В случае поднятия `NoDishError` в любом из методов (см. задачу 2) мы бы хотели, чтобы меню оставалось таким, каким оно было до вызова данного метода. Напиши декоратор `transactional`, который так и сделает + в случае, если была поймана ошибка, выведет нам "Error occured. Saved the last state of menu".
#
# ```python
# class CoffeeShop:
#     @transactional
#     @check_id()
#     @logger("some_file.txt")
#     def delete_dish(...): ...
#
#     @transactional
#     @check_id(error_0_left=True)
#     def form_order(...): ...
# ```

# %%
# TODO

# %%
# TODO - скопируй сюда код CoffeeShop из задачи 3, добавь этот декоратор к методу delete_dish, restock_dish, form_order
# и напиши примеры использования этих методов

# %% [markdown]
# ## Задача 5. Аутентификация. (3 балла)
#
# Напиши декоратор `needs_auth(roles)`, который перед вызовом метода проверяет, был ли передан в качестве аргумента по названию (`user=` в kwargs) пользователь с ролью из списка `roles`. Если нет - поднимает ошибку `AuthentificationError` (напиши её сам) и не выполняет метод.

# %% [markdown]
# Вопрос: Надо ли поменять код методов, чтобы он мог принимать этого `user` по названию? Если да, то как?
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %% [markdown]
# Вопрос: В каком из вариантов (А, Б, никакой, оба) `transactional` сможет поймать ошибку, если она будет поднята `needs_auth`? Почему?
#
# ```python
# # Вариант А.
# class CoffeeShop:
#     @transactional
#     @needs_auth(["admin"])
#     def add_dish(...): ...
# ```
#
# ```python
# # Вариант Б.
# class CoffeeShop:
#     @needs_auth(["admin"])
#     @transactional
#     def add_dish(...): ...
# ```
#
# <b><font color="#FF69B4"> Ваш ответ здесь </font></b>

# %%
# TODO

# %%
# TODO - скопируй сюда код CoffeeShop из задачи 4, если надо - поменяй код методов
# Добавь этот декоратор к методу add_dish, роль - admin

# %%
# И напиши пример(ы) использования данного метода с учётом user'а
